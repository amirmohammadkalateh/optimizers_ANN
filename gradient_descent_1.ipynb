# %% [markdown]
# <a href="https://colab.research.google.com/github/amirmohammadkalateh/optimizers_ANN/blob/main/gradient_descent_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def func(x) :
  return x**2

def func_grad(x) :
    return 2*x

# %%
def gradient_descent(lr , func_grad) :
  x = -10
  x_values = [x]
  for i in range (10) :
    x -= lr*func_grad(x)
    x_values.append(x)
    print("iteration 10, x : %s"%x)
  return x_values

# %%
import numpy as np
import matplotlib.pyplot as plt

def search_path (x_vals , func) :
  x_line = np.arange(-15 , 15 , 0.01)
  plt.plot(x_line, [func(x) for x in x_line])
  plt.plot(x_vals, [func(x) for x in x_vals] , "ro-")

# %%
x_values = gradient_descent(0.1, func_grad)
search_path(x_values, func)
# Out:
# iteration 10, x : -8.0
# iteration 10, x : -6.4
# iteration 10, x : -5.12
# iteration 10, x : -4.096
# iteration 10, x : -3.2768
# iteration 10, x : -2.62144
# iteration 10, x : -2.0971520000000003
# iteration 10, x : -1.6777216000000004
# iteration 10, x : -1.3421772800000003
# iteration 10, x : -1.0737418240000003
